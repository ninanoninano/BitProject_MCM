# %%
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('')

# %% [markdown]
# 데이터 분석

# %%
# 데이터 정보 보기
df.info()

# 데이터 상위 5행 보기
df.head()

# 데이터 하위 5행 보기
df.tail()

# 데이터 (행, 열) 크기 확인 
df.shape()

# 데이터 통계보기
df.describe()

# 컬럼데이터별 건수 나열
df['컬럼명'].value_count()

#데이터 결측치 확인
df['컬럼명'].isnull().sum()

# 두 변수간 상관 관계 분석
df.corr()

# %%
# 차트그리기(matplotlib)
plt.title('test')
plt.plot(hist.history['acc'], label='acc') # 출력 그래프 데이터
plt.plot(hist.history['val_acc'], label='val_acc')
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.legend() #범례
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.show()

# 산점도 그리기
plt.scatter(x,y)

# 막대그래프 그리기
plt.bar(x,y)

# 히스토그램 그리기
plt.hist(values)

# %%
# 차트 그리기 (seaborn) 히트맵
import seaborn as sns

sns.heatmap(df.corr(), annot=True)

# 차트 그리기 (seaborn) pairplot

sns.pairplot(data=df,
             x_vars=['',''],
             y_vars=[''])

# %% [markdown]
# 데이터 전처리

# %%
# 특정컬럼 삭제
x = df.drop(['컬럼명'], axis=1)
# axis = 0 : 행 / axis = 1 : 열

# 값 변경
df['컬럼'].replace('변경전 값', '변경후 값', inplace=True #바로 적용, 꼭 하기 !!)

# 전체
df.replace('변경전 값', '변경후 값', inplace=True #바로 적용, 꼭 하기 !!)

# %%
# 특정 값이 있는 행만 가져오기
df[df['컬럼']=='특정값']

# 특정 값의 개수 확인하기
(df['컬럼'] == '특정값').sum()

# 전체 값의 개수 확인
df.apply(lambda x: x.isin(['비교값']).sum())

# null값 처리
df['컬럼'].fillna('변경값', inplace=True)

# 결측치 바로 앞 값으로 채우기
df['컬럼'].fillna(method='ffill')

# 결측치 바로 뒤 값으로 채우기
df['컬럼'].fillna(method='bfill')

# 결측치 삭제
df,dropna()
df,dropna(subset=['컬럼명'])
df,dropna(axis=0, how='all')
df,dropna(axis=1, how='any')

# 0: 행, all: 전체 null일 경우
# 1: 컬럼, any: 하나라도 null일 경우

# %%
# 이상치 데이터 확인
sns.boxplot(x= '', y='', data=df)

# 이상치 데이터 제거
s_ol_data = pd.Series(ol_data)
level_1q = s_ol_data.quantile(0.25)
level_3q = s_ol_data.quantile(0.75)
IQR = level_3q - level_1q
rev_range = 3  # 제거 범위 조절 변수
dff = s_ol_data[(s_ol_data <= level_3q + (rev_range * IQR)) & (s_ol_data >= level_1q - (rev_range * IQR))]
dff = dff.reset_index(drop=True)

# %%
# 데이터 타입 변경
df['컬럼명'] = df['컬럼명'].astype(타입)
# 타입 예 : int, object

# 특정 데이터 타입의 컬럼 선택
c = df.select_dtypes(include='데이터타입')

# %%
# 문자를 숫자로 변경(라벨 인코딩)
from sklearn.perprocessing import LabelEncoder

le = LabelEncoder()
df['컬럼명'] = le.fit_transform(df['컬럼명'])

# 문자를 숫자로 변경(원핫인코딩)>>
pd.get_dummies(데이터프레임 또는 열)
pd.get_dummies(데이터 프레임, columns = ['컬럼명'])

# 결측값에서 원 핫 인코딩이 필요한 경우
pd.get_dummies(df['컬럼'], dummy_na = True)

# 첫 번째 카테고리(원 핫 인코딩 삭제)
pd.get_dummies(df['컬럼'], drop_first=True)

# %% [markdown]
# 데이터 분리

# %%
# Feature(x)/ Target(y) 분리
x = df.drop(columns=['Y가 있는 컬럼명']).values
y = df['Y가 있는 컬럼명'].valse

#학습 데이터(train set)와 검증데이터(test set)로 분리
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, shuffle=True, stratify=y, random_state=0)

test_size : 검증 데이터 비율(0~1)
shuffle : 데이터 분리 전 데이터를 섞을지 여부
stratify : 원래의 데이터(Y)의 분표 비율 유지
random_state : 데이터를 섞을 때 사용할 시드 값

# %% [markdown]
# 데이터 스케일링
#
# >
#
#
# 상대적인 크기 차이를 제거하여 영향을 최소화

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

scaler = MinMaxScaler() # 정규화: 최대값 1, 최소값 0
scaler = StandardScaler() # 표준화: 평균값 0, 표준편차 1

x_train = scaler.fit_transform(x_train)
x_test = scaler.trabsform(x_test)

# fit_transform : train set 에만 사용
# transform : train set으로부터 학습된 평균 시간과 표준편차 값을 test set에 적용
	    test set에도 fit 적용 시 새로운 평균과 표준편차 값이 생성되어 성능을 평가할 수 없게 됌

# %% [markdown]
# 머신러닝

# %%
# 로지스틱 회귀
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
acc = accuracy_score(y_test, y_pred)

#선형 회귀
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
acc = accuracy_score(y_test, y_pred)

# 결정트리
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=10, random_state=42)
# 트리의 최대 깊이, 난수 seed값

model.fit(x_train, y_train)
model.score(x_test, y_test)

# 랜덤포레스트
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier(n_eimators=20, stmax_depth=10, random_state=42)
#트리의 개수

model.fit(x_train, y_train)
predicted = model.predict(x_test)
acc = accuracy_score(y_test, y_pred)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Droput  
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential([           
	Input(shape=개수,)),
	Dense(64, activation=’relu‘),
	Dropout(0.2),      # 과적합 방지 함수
	Dense(32, activation=’relu‘),
	Dropout(0.2),
	Dense(16, activation=’relu‘),
	Dropout(0.2),
	Dense(1, activation=’sigmoid‘)
])

# %%
# 이진분류
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
                                         손실함수               평가기준

# 다중분류
model.add(Dense(최종 output개수, activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
# Y 원핫인코딩이 된 경우
                                         
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Y 원핫인코딩이 안 된 경우

# 예측
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse', metrics=['mse','mae'])

# %%
# callback                                                      화면출력 여부
es = arlyStopping(monitor='val_loss', patience=4, mode='min', verbose=1)
# val_loss(출력값과 정답의 차이)값이 4 epochs 안에 개선되지 않으면 중지 

mc = ModelCheakpoint('my_checkpoint.h5', monitor='val_loss', save_best_only=True, verbose=1)
# val_loss 값이 개선되면 my_checkpoint.h5으로 저장

# %%
# 모델훈련

hist = model.fit(x_train, y_train,
batch_size=32,
epochs=100,
callback=[es, mc],
validation_data=(x_test, y_test),
verbose=1)

# %%
# 그래프 그리기
# ACC
plt.title('제목')
plt.plot(hist.history['acc'], label='acc') # 출력 그래프 데이터
plt.plot(hist.history['val_acc'], label='val_acc')
plt.legend(acc, val_acc) #범례
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.show()

#Loss
plt.title('제목')
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.legend(loss, val_loss) #범례
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.show()

# %%
# 성능평가 하기
# 분류모델의 성능평가 구현
y_pred= forest.predict(x_test) # 데이터 예측

#Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(x_test, y_pred)
print(cm)

#Precision(정밀도)
from sklearn.metrics import recall_score
rs = recall_score(x_test, y_pred, pos_label=1)
print('Recall(재현율): %4f' % rs)

#F1 Score
from sklearn.metrics import f1_score
fs = f1_score(x_test, y_pred, pos_label=1)
print('F1 Score: %4f' % fs)

#Accuracy(정확도)
from sklearn.metrics import accuracy_score
accs = accuracy_score(x_test, y_pred)
print('Accuracy(정확도): %4f' % accs)

#Classification Report (평가지표-Precision, Recall, F1) 한번에 출력
from sklearn.metrics import classification_report
cr = classification_report(x_test, y_pred, target_name=['class 0', 'class 1'])
print(cr)
